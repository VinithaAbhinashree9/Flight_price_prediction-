# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(r'C:\Users\srivi\OneDrive\Desktop\flight_price_prediction\flight_price_prediction_dataset\Clean_Dataset.csv')

# %%
data.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
data.stops = pd.factorize(data['stops'])[0]

# %%
data
# Out:
#         Unnamed: 0   airline   flight source_city departure_time  stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening      0
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning      0
# 2                2   AirAsia   I5-764       Delhi  Early_Morning      0
# 3                3   Vistara   UK-995       Delhi        Morning      0
# 4                4   Vistara   UK-963       Delhi        Morning      0
# ...            ...       ...      ...         ...            ...    ...
# 300148      300148   Vistara   UK-822     Chennai        Morning      1
# 300149      300149   Vistara   UK-826     Chennai      Afternoon      1
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning      1
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning      1
# 300152      300152   Vistara   UK-822     Chennai        Morning      1
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
pd.get_dummies(data['airline'], prefix='airline')
# Out:
#         airline_AirAsia  airline_Air_India  airline_GO_FIRST  airline_Indigo  \
# 0                 False              False             False           False
# 1                 False              False             False           False
# 2                  True              False             False           False
# 3                 False              False             False           False
# 4                 False              False             False           False
# ...                 ...                ...               ...             ...
# 300148            False              False             False           False
# 300149            False              False             False           False
# 300150            False              False             False           False
# 300151            False              False             False           False
# 300152            False              False             False           False
#
#         airline_SpiceJet  airline_Vistara
# ...

# %%
data = data.join(pd.get_dummies(data['source_city'], prefix='source_city')).drop('source_city', axis=1)
data = data.join(pd.get_dummies(data['destination_city'], prefix='destination_city')).drop('destination_city', axis=1)
data = data.join(pd.get_dummies(data['departure_time'], prefix='departure_time')).drop('departure_time', axis=1)
data = data.join(pd.get_dummies(data['arrival_time'], prefix='arrival_time')).drop('arrival_time', axis=1)

# %%
data
# Out:
#         Unnamed: 0   airline   flight  stops     class  duration  days_left  \
# 0                0  SpiceJet  SG-8709      0   Economy      2.17          1
# 1                1  SpiceJet  SG-8157      0   Economy      2.33          1
# 2                2   AirAsia   I5-764      0   Economy      2.17          1
# 3                3   Vistara   UK-995      0   Economy      2.25          1
# 4                4   Vistara   UK-963      0   Economy      2.33          1
# ...            ...       ...      ...    ...       ...       ...        ...
# 300148      300148   Vistara   UK-822      1  Business     10.08         49
# 300149      300149   Vistara   UK-826      1  Business     10.42         49
# 300150      300150   Vistara   UK-832      1  Business     13.83         49
# 300151      300151   Vistara   UK-828      1  Business     10.00         49
# 300152      300152   Vistara   UK-822      1  Business     10.08         49
#
# ...

# %%
data['price'].fillna(data['price'].mean())
# Out:
# 0          5953
# 1          5953
# 2          5956
# 3          5955
# 4          5955
#           ...
# 300148    69265
# 300149    77105
# 300150    79099
# 300151    81585
# 300152    81585
# Name: price, Length: 300153, dtype: int64

# %%
data['price'].fillna(data['price'].median())
# Out:
# 0          5953
# 1          5953
# 2          5956
# 3          5955
# 4          5955
#           ...
# 300148    69265
# 300149    77105
# 300150    79099
# 300151    81585
# 300152    81585
# Name: price, Length: 300153, dtype: int64

# %%
data['price'].fillna(data['price'].mode()[0])
# Out:
# 0          5953
# 1          5953
# 2          5956
# 3          5955
# 4          5955
#           ...
# 300148    69265
# 300149    77105
# 300150    79099
# 300151    81585
# 300152    81585
# Name: price, Length: 300153, dtype: int64

# %%
q1=np.quantile(data['price'],0.25) 
q3=np.quantile(data['price'],0.75)

# %%
iqr=q3-q1
lower_bound=q1-1.5*iqr
upper_bound=q3+1.5*iqr

# %%
data['price']=data[(data['price']<upper_bound)&(data['price']>lower_bound)]['price']

# %%
data.head(5)
# Out:
#    Unnamed: 0   airline   flight  stops    class  duration  days_left   price  \
# 0           0  SpiceJet  SG-8709      0  Economy      2.17          1  5953.0
# 1           1  SpiceJet  SG-8157      0  Economy      2.33          1  5953.0
# 2           2   AirAsia   I5-764      0  Economy      2.17          1  5956.0
# 3           3   Vistara   UK-995      0  Economy      2.25          1  5955.0
# 4           4   Vistara   UK-963      0  Economy      2.33          1  5955.0
#
#    source_city_Bangalore  source_city_Chennai  ...  departure_time_Evening  \
# 0                  False                False  ...                    True
# 1                  False                False  ...                   False
# 2                  False                False  ...                   False
# 3                  False                False  ...                   False
# 4                  False                False  ...                   False
#
# ...

# %%
data.drop(['price',''],axis=1,inplace=True)

# %%
data.drop_duplicates(inplace=True) 
data.dropna(inplace=True)

# %%
data
# Out:
#         Unnamed: 0   airline   flight  stops     class  duration  days_left  \
# 0                0  SpiceJet  SG-8709      0   Economy      2.17          1
# 1                1  SpiceJet  SG-8157      0   Economy      2.33          1
# 2                2   AirAsia   I5-764      0   Economy      2.17          1
# 3                3   Vistara   UK-995      0   Economy      2.25          1
# 4                4   Vistara   UK-963      0   Economy      2.33          1
# ...            ...       ...      ...    ...       ...       ...        ...
# 300148      300148   Vistara   UK-822      1  Business     10.08         49
# 300149      300149   Vistara   UK-826      1  Business     10.42         49
# 300150      300150   Vistara   UK-832      1  Business     13.83         49
# 300151      300151   Vistara   UK-828      1  Business     10.00         49
# 300152      300152   Vistara   UK-822      1  Business     10.08         49
#
# ...

# %% [markdown]
# Feature engineering:

# %%
data.describe()
# Out:
#           Unnamed: 0          stops       duration      days_left  \
# count  300030.000000  300030.000000  300030.000000  300030.000000
# mean   150034.147885       0.924188      12.220126      26.012009
# std     86638.319536       0.398049       7.192515      13.557878
# min         0.000000       0.000000       0.830000       1.000000
# 25%     75007.250000       1.000000       6.830000      15.000000
# 50%    150014.500000       1.000000      11.250000      26.000000
# 75%    225048.750000       1.000000      16.170000      38.000000
# max    300152.000000       2.000000      49.830000      49.000000
#
#                price
# count  300030.000000
# mean    20855.326674
# std     22638.775853
# min      1105.000000
# 25%      4783.000000
# 50%      7425.000000
# 75%     42521.000000
# max     98972.000000

# %%
from sklearn.preprocessing import LabelEncoder 
le=LabelEncoder() 
data['price']=le.fit_transform(data['price'])

# %%
from sklearn.preprocessing import MinMaxScaler ,StandardScaler
scaler=StandardScaler() 
data['days_left']=scaler.fit_transform(data['days_left'].values.reshape(-1,1))

# %%
X=data.drop(['duration'],axis=1) 
y=data['duration']

# %%
X, y = data.drop('duration', axis=1), data['duration']

# %%
from sklearn.preprocessing import LabelEncoder 
le=LabelEncoder() 
data['price']=le.fit_transform(data['price'])

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

reg = RandomForestRegressor(n_jobs=-1, random_state=42)
reg.fit(X_train, y_train)

# Evaluate on the test set
y_pred = reg.predict(X_test)
print("R2 score:", r2_score(y_test, y_pred))            
print("MAE:", mean_absolute_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 4
#       1 from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
#       3 reg = RandomForestRegressor(n_jobs=-1, random_state=42)
# ----> 4 reg.fit(X_train, y_train)
#       6 # Evaluate on the test set
#       7 y_pred = reg.predict(X_test)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 reg.score(X_test, y_test)
#       2 import warnings
#       3 warnings.filterwarnings('ignore')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:653, in RegressorMixin.score(self, X, y, sample_weight)
#     611 """Return :ref:`coefficient of determination <r2_score>` on test data.
#     612
#     613 The coefficient of determination, :math:`R^2`, is defined as
#    (...)    648 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     649 """
#     651 from sklearn.metrics import r2_score
# --> 653 y_pred = self.predict(X)
#     654 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_forest.py:1063, in ForestRegressor.predict(self, X)
#    1044 def predict(self, X):
#    1045     """
# ...
